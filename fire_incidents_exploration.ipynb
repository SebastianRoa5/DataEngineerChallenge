# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata(domain="data.sfgov.org",app_token=None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.sfgov.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wr8u-xric",content_type='csv', limit=1000000, where="data_loaded_at > '2025-05-25T02:21:08.000'")


# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.columns = results_df.iloc[0,:]
results_df = results_df[1:]

# %%
pd.set_option('display.max_columns' ,None)

# %%
results_df.describe(include='all')
# Out:
# 0      incident_number exposure_number   id address incident_date call_number  \
# count                0               0    0       0             0           0
# unique               0               0    0       0             0           0
# top                NaN             NaN  NaN     NaN           NaN         NaN
# freq               NaN             NaN  NaN     NaN           NaN         NaN
#
# 0      alarm_dttm arrival_dttm close_dttm city zipcode battalion station_area  \
# count           0            0          0    0       0         0            0
# unique          0            0          0    0       0         0            0
# top           NaN          NaN        NaN  NaN     NaN       NaN          NaN
# freq          NaN          NaN        NaN  NaN     NaN       NaN          NaN
#
# 0       box suppression_units suppression_personnel ems_units ems_personnel  \
# count     0                 0                     0         0             0
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   incident_number                               100 non-null    object
#  1   exposure_number                               100 non-null    object
#  2   id                                            100 non-null    object
#  3   address                                       100 non-null    object
#  4   incident_date                                 100 non-null    object
#  5   call_number                                   100 non-null    object
#  6   alarm_dttm                                    100 non-null    object
#  7   arrival_dttm                                  100 non-null    object
#  8   close_dttm                                    100 non-null    object
# ...

# %%
pd.read_json(results_df.to_json())
# Out:
# /var/folders/k0/gdj4sssj1mn5_1l42hvf41v40000gn/T/ipykernel_90442/4175018606.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(results_df.to_json())
#      incident_number  exposure_number         id  \
# 1           16010340                0  160103400
# 2           16010347                0  160103470
# 3           16010355                0  160103550
# 4           16010363                0  160103630
# 5           16010369                0  160103690
# ..               ...              ...        ...
# 96          16010823                0  160108230
# 97          16010828                0  160108280
# 98          16010830                0  160108300
# 99          16010842                0  160108420
# 100         16010852                0  160108520
#
#                                   address            incident_date  \
# ...

# %%
results_df
# Out:
# 0      incident_number exposure_number         id                     address  \
# 1             16010340               0  160103400  EDINBURGH ST/GENEVA AVENUE
# 2             16010347               0  160103470      POTRERO AV/22ND STREET
# 3             16010355               0  160103550             1685 7TH AVENUE
# 4             16010363               0  160103630            761 MINNA STREET
# 5             16010369               0  160103690       655 MONTGOMERY STREET
# ...                ...             ...        ...                         ...
# 705270        06054938               0  060549380    Ashbury St. / Haight St.
# 705271        06054939               0  060549390              780 Fulton St.
# 705272        06054940               0  060549400                 555 9th St.
# 705273        06054942               0  060549420              847 Castro St.
# 705274        06054943               0  060549430                481 Eddy St.
#
# ...

# %%
results_df.shape
# Out:
# (705274, 66)
